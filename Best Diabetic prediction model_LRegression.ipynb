# %% [markdown]
# <a href="https://colab.research.google.com/github/abhijr077/Best-Diabetes-Prediction-Model/blob/main/Best%20Diabetic%20prediction%20model_LRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pycaret pandas shap
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 535.7/535.7 kB 8.2 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
from pycaret.classification import*

# %%
import pandas as pd
df = pd.read_csv('/content/diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %% [markdown]
# TRAIN AND EVALUATION

# %%
clf1 = setup(data = df, target = 'Outcome')
best = compare_models()
# Out:
# <style type="text/css">
# #T_b20f0_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b20f0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b20f0_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_b20f0_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b20f0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b20f0_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_b20f0_row0_col1" class="data row0 col1" >5238</td>
#     </tr>
#     <tr>
#       <th id="T_b20f0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b20f0_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_b20f0_row1_col1" class="data row1 col1" >Outcome</td>
#     </tr>
#     <tr>
#       <th id="T_b20f0_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
print(best)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=5238, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
predict_model(best)
# Out:
# <style type="text/css">
# </style>
# <table id="T_7aac0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7aac0_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_7aac0_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_7aac0_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_7aac0_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_7aac0_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_7aac0_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_7aac0_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_7aac0_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7aac0_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
predict_model(best,df.tail())
# Out:
# <style type="text/css">
# </style>
# <table id="T_408e0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_408e0_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_408e0_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_408e0_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_408e0_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_408e0_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_408e0_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_408e0_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_408e0_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_408e0_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
#Save model

# %%
save_model(best,model_name='Best Model For Diabetes Prediction')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['Pregnancies', 'Glucose',
#                                               'BloodPressure', 'SkinThickness',
#                                               'Insulin', 'BMI',
#                                               'DiabetesPedigreeFunction',
#                                               'Age'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty_features=False,
#                                                                missing_values=nan,
# ...
